# %%
import wrangle as w

# %%
df = w.prep_store_data()

# %%
df.head()
# Out:
#          order_id order_date  ship_date       ship_mode    segment  \
# 0  CA-2016-152156 2016-11-08 2016-11-11    Second Class   Consumer
# 1  CA-2016-152156 2016-11-08 2016-11-11    Second Class   Consumer
# 2  CA-2016-138688 2016-06-12 2016-06-16    Second Class  Corporate
# 3  US-2015-108966 2015-10-11 2015-10-18  Standard Class   Consumer
# 4  US-2015-108966 2015-10-11 2015-10-18  Standard Class   Consumer
#
#          country             city       state  postal_code     sales  ...  \
# 0  United States        Henderson    Kentucky        42420  261.9600  ...
# 1  United States        Henderson    Kentucky        42420  731.9400  ...
# 2  United States      Los Angeles  California        90036   14.6200  ...
# 3  United States  Fort Lauderdale     Florida        33311  957.5775  ...
# 4  United States  Fort Lauderdale     Florida        33311   22.3680  ...
#
#    discount    profit    customer_name         category sub_category  \
# ...

# %%
df.groupby('discount')['sales'].agg(['mean', 'median', 'count'])

# %%
df.groupby('discount')['cost'].agg(['mean', 'median', 'count'])

# %%
df.groupby('discount')['profit'].agg(['mean', 'median', 'count'])

# %%
df[df['discount'] == .1]
